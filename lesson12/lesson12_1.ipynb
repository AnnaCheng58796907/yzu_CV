# %% [markdown]
# ### 影像增強與頻域分析

# %%
# 直方圖
import matplotlib.pyplot as plt

seq = [1, 2, 3, 4, 5]           # 像素值
times = [2, 1, 2, 1, 3]         # 出現次數
plt.plot(seq,times, "-o")       # 繪含標記的圖
plt.axis([0, 6, 0, 4])          # 建立軸大小
plt.xlabel("Pixel Value")       # 像素值
plt.ylabel("Times")             # 出現次數
plt.show()

# %%
# 直方圖
import matplotlib.pyplot as plt
import numpy as np

times = [2, 1, 2, 1, 3]         # 出現次數
N = len(times)                  # 計算長度
x = np.arange(N)                # 長條圖X軸座標
width = 0.5                     # 長條圖寬度
plt.bar(x, times, width)        # 繪製長方
plt.xlabel("Pixel Value")       # 像素值
plt.ylabel("Times")             # 出現次數
plt.xticks(x, ("1", "2", "3", "4", "5"))
plt.show()

# %%
# 正規化直方圖-次數改頻率
import matplotlib.pyplot as plt

seq = [1, 2, 3, 4, 5]               # 像素值
freq = [2/9, 1/9, 2/9, 1/9, 3/9]    # 出現頻率(正規化/數值相加後為1)
plt.plot(seq, freq, "-o")           # 繪含標記的圖
plt.axis([0, 6, 0, 0.5])            # 建立軸大小
plt.xlabel("Pixel Value")           # 像素值
plt.ylabel("Frequency")             # 出現頻率
plt.show()

# %%
# 正規化直方圖-次數改頻率
# 使用長條圖
import matplotlib.pyplot as plt
import numpy as np
freq = [2/9, 1/9, 2/9, 1/9, 3/9]    # 出現頻率
N = len(freq)                       # 計算長度
x = np.arange(N)                    # 長條圖x軸座標
width = 0.35                        # 長條圖寬度
plt.bar(x, freq, width)             # 繪製長條圖                        
plt.xlabel("Pixel Value")           # 像素值
plt.ylabel("Freqency")              # 出現頻率
plt.xticks(x, ('1', '2', '3', '4', '5'))
plt.show()

# %%
# 繪製影像的直方圖
# 使用Matplotlib 的 hist() 函式
import cv2
import matplotlib.pyplot as plt

src = cv2.imread("snow.jpg", cv2.IMREAD_GRAYSCALE)
cv2.imshow("Src", src)
plt.axis("off")
plt.imshow(cv2.cvtColor(src, cv2.COLOR_BGR2RGB))
plt.show()
plt.hist(src.ravel(), 256)          # 降維再繪製直方圖
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 繪製影像的直方圖
# 使用Matplotlib 的 hist() 函式
# 設定區間
import cv2
import matplotlib.pyplot as plt

src = cv2.imread("snow.jpg", cv2.IMREAD_GRAYSCALE)
cv2.imshow("Src", src)
plt.axis("off")
plt.imshow(cv2.cvtColor(src, cv2.COLOR_BGR2RGB))
plt.show()
plt.hist(src.ravel(), 20)          # 降維再繪製直方圖
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 使用OpenCV 取得直方圖數據
import cv2
import matplotlib.pyplot as plt

src = cv2.imread("snow.jpg", cv2.IMREAD_GRAYSCALE)
cv2.imshow("Src", src)
plt.axis("off")
plt.imshow(cv2.cvtColor(src, cv2.COLOR_BGR2RGB))
plt.show()
hist = cv2.calcHist([src], [0], None, [256], [0, 256]) # 直方圖統計資料
print(f"資料類型 = {type(hist)}")
print(f"資料外觀 = {hist.shape}")
print(hist.ravel().shape)
print(f"資料大小 = {hist.size}")
print(f"資料內容 \n{hist}")
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 資料類型 = <class 'numpy.ndarray'>
# 資料外觀 = (256, 1)
# (256,)
# 資料大小 = 256
# 資料內容
# [[   5.]
#  [   5.]
#  [   3.]
#  [   7.]
#  [  11.]
#  [   9.]
#  [   9.]
#  [  17.]
#  [  18.]
#  [  25.]
#  [  21.]
#  [  25.]
#  [  27.]
#  [  31.]
#  [  28.]
#  [  52.]
#  [  42.]
#  [  43.]
#  [  53.]
#  [  53.]
#  [  73.]
#  [  48.]
#  [  62.]
#  [  68.]
#  [  60.]
#  [  59.]
#  [  96.]
#  [  88.]
#  [  87.]
#  [  85.]
#  [ 107.]
#  [  95.]
#  [ 114.]
#  [ 110.]
#  [ 147.]
#  [ 140.]
#  [ 134.]
#  [ 153.]
#  [ 139.]
#  [ 164.]
#  [ 181.]
#  [ 164.]
#  [ 171.]
#  [ 180.]
#  [ 202.]
#  [ 193.]
#  [ 194.]
#  [ 186.]
#  [ 215.]
#  [ 237.]
#  [ 283.]
#  [ 290.]
#  [ 253.]
#  [ 303.]
#  [ 284.]
#  [ 314.]
#  [ 340.]
#  [ 376.]
#  [ 377.]
#  [ 382.]
#  [ 379.]
#  [ 359.]
#  [ 406.]
#  [ 356.]
#  [ 393.]
#  [ 420.]
#  [ 387.]
#  [ 398.]
#  [ 419.]
#  [ 372.]
#  [ 399.]
#  [ 391.]
#  [ 369.]
#  [ 397.]
#  [ 400.]
#  [ 393.]
#  [ 390.]
#  [ 406.]
#  [ 360.]
#  [ 404.]
#  [ 394.]
#  [ 409.]
#  [ 430.]
#  [ 434.]
#  [ 438.]
#  [ 418.]
#  [ 412.]
#  [ 463.]
#  [ 415.]
#  [ 390.]
#  [ 441.]
#  [ 452.]
#  [ 451.]
#  [ 426.]
#  [ 440.]
#  [ 472.]
#  [ 507.]
#  [ 470.]
#  [ 461.]
#  [ 484.]
#  [ 502.]
#  [ 483.]
#  [ 494.]
#  [ 501.]
#  [ 513.]
#  [ 491.]
#  [ 491.]
#  [ 503.]
#  [ 534.]
#  [ 536.]
#  [ 506.]
#  [ 516.]
#  [ 569.]
#  [ 576.]
#  [ 560.]
#  [ 551.]
#  [ 583.]
#  [ 579.]
#  [ 559.]
#  [ 618.]
#  [ 650.]
#  [ 803.]
#  [ 807.]
#  [ 923.]
#  [ 947.]
#  [ 998.]
#  [1113.]
#  [1256.]
#  [1353.]
#  [1509.]
#  [1712.]
#  [1522.]
#  [1498.]
#  [1588.]
#  [1635.]
#  [1511.]
#  [1387.]
#  [1207.]
#  [ 972.]
#  [ 935.]
#  [ 986.]
#  [ 925.]
#  [ 896.]
#  [ 885.]
#  [ 854.]
#  [ 843.]
#  [ 768.]
#  [ 777.]
#  [ 806.]
#  [ 790.]
#  [ 819.]
#  [ 759.]
#  [ 829.]
#  [ 833.]
#  [ 804.]
#  [ 844.]
#  [ 850.]
#  [ 942.]
#  [ 843.]
#  [ 820.]
#  [ 767.]
#  [ 801.]
#  [ 709.]
#  [ 694.]
#  [ 679.]
#  [ 680.]
#  [ 663.]
#  [ 650.]
#  [ 608.]
#  [ 703.]
#  [ 641.]
#  [ 674.]
#  [ 740.]
#  [ 744.]
#  [ 819.]
#  [ 867.]
#  [ 785.]
#  [ 931.]
#  [ 926.]
#  [ 978.]
#  [1086.]
#  [1199.]
#  [1260.]
#  [1329.]
#  [1529.]
#  [1976.]
#  [2245.]
#  [2393.]
#  [1886.]
#  [1838.]
#  [1792.]
#  [1182.]
#  [ 852.]
#  [ 886.]
#  [ 834.]
#  [ 862.]
#  [ 781.]
#  [ 741.]
#  [ 656.]
#  [ 642.]
#  [ 636.]
#  [ 648.]
#  [ 611.]
#  [ 609.]
#  [ 578.]
#  [ 471.]
#  [ 417.]
#  [ 425.]
#  [ 371.]
#  [ 400.]
#  [ 385.]
#  [ 392.]
#  [ 385.]
#  [ 428.]
#  [ 458.]
#  [ 465.]
#  [ 457.]
#  [ 470.]
#  [ 435.]
#  [ 422.]
#  [ 404.]
#  [ 368.]
#  [ 391.]
#  [ 377.]
#  [ 347.]
#  [ 381.]
#  [ 347.]
#  [ 336.]
#  [ 333.]
#  [ 341.]
#  [ 403.]
#  [ 307.]
#  [ 328.]
#  [ 305.]
#  [ 263.]
#  [ 314.]
#  [ 298.]
#  [ 223.]
#  [ 224.]
#  [ 212.]
#  [ 210.]
#  [ 194.]
#  [ 160.]
#  [ 159.]
#  [ 150.]
#  [ 169.]
#  [ 131.]
#  [ 112.]
#  [ 131.]
#  [ 101.]
#  [  80.]
#  [  87.]
#  [  55.]
#  [  55.]
#  [  51.]
#  [  97.]]

# %%
# 使用OpenCV 取得直方圖數據，
# 並繪製直方圖
import cv2
import matplotlib.pyplot as plt

src = cv2.imread("snow.jpg", cv2.IMREAD_GRAYSCALE)
cv2.imshow("Src", src)
plt.axis("off")
plt.imshow(cv2.cvtColor(src, cv2.COLOR_BGR2RGB))
plt.show()
hist = cv2.calcHist([src], [0], None, [256], [0, 256]) # 直方圖統計資料
plt.plot(hist)                                         # 用plot()繪直方圖
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 使用OpenCV 取得直方圖數據，
# 並繪製直方圖-長條圖
import cv2
import matplotlib.pyplot as plt
import numpy as np

src = cv2.imread("snow.jpg", cv2.IMREAD_GRAYSCALE)
cv2.imshow("Src", src)
plt.axis("off")
plt.imshow(cv2.cvtColor(src, cv2.COLOR_BGR2RGB))
plt.show()
hist = cv2.calcHist([src], [0], None, [256], [0, 256]) # 直方圖統計資料
N = len(hist)
x = np.arange(N)
width = 0.35
plt.bar(range(256), hist.ravel(), width)    # 繪製長條圖-要提供一維資料                        
plt.xlabel("Pixel Value")                   # 像素值
plt.ylabel("Times")                         # 出現頻率
plt.xticks(np.arange(0, 256, 32))
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 使用OpenCV 取得彩色影像的直方圖數據，
# 並繪製直方圖
import cv2
import matplotlib.pyplot as plt

src = cv2.imread("macau.jpg", cv2.IMREAD_COLOR)
cv2.imshow("Src", src)
plt.axis("off")
plt.imshow(cv2.cvtColor(src, cv2.COLOR_BGR2RGB))
plt.show()
b = cv2.calcHist([src], [0], None, [256], [0, 256]) # B 通道統計資料 
g = cv2.calcHist([src], [1], None, [256], [0, 256]) # G 通道統計資料 
r = cv2.calcHist([src], [2], None, [256], [0, 256]) # R 通道統計資料
plt.plot(b, color="blue", label="B channel")        # 用plot()繪 B 通道
plt.plot(g, color="green", label="G channel")       # 用plot()繪 G 通道
plt.plot(r, color="red", label="R channel")         # 用plot()繪 R 通道
plt.legend(loc="best")
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 取得並繪製影像裡特定區塊的直方圖
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 設定全域字體為黑體，解決中文亂碼
plt.rcParams['font.sans-serif'] = ['SimHei']    # 指定字型（可換成你有安裝的其他中文字型名稱）
plt.rcParams['axes.unicode_minus'] = False      # 解決負號顯示錯誤問題

src = cv2.imread("macau.jpg", cv2.IMREAD_GRAYSCALE)
mask = np.zeros(src.shape[:2], np.uint8)                    # 建立影像遮罩影像
mask[20:200, 50:400] = 255                                  # 在遮罩影像內建立遮罩
aftermask = cv2.bitwise_and(src, src, mask=mask)
hist = cv2.calcHist([src], [0], None, [256], [0, 256])      # 灰階統計資料
hist_mask = cv2.calcHist([src], [0], mask, [256], [0, 256]) # 遮罩統計資料 
# subplot()第一個2是代表垂直有2張圖, 第二個2是代表左右有2張圖，第三個參數是代表子圖編號
plt.subplot(221)                                            # 建立子圖1
plt.title("第一張")
plt.imshow(src, 'gray')                                     # 灰階顯示第1張圖
plt.subplot(222)                                            # 建立子圖2
plt.title("第二張")
plt.imshow(mask, 'gray')                                    # 灰階顯示第2張圖
plt.subplot(223)                                            # 建立子圖3
plt.title("第三張")
plt.imshow(aftermask, 'gray')                               # 灰階顯示第2張圖
plt.subplot(224)                                            # 建立子圖4
plt.title("第四張")
plt.plot(hist, color="blue", label="Src Image")
plt.plot(hist_mask, color="red", label="Mask")
plt.legend(loc="best")
plt.tight_layout()                                          # 自動調整排版
plt.show()

# %%
# 直方圖均衡化：
# 使用equalizeHist() 函式

import cv2
import matplotlib.pyplot as plt

# 設定全域字體為黑體，解決中文亂碼
plt.rcParams['font.sans-serif'] = ['SimHei']    # 指定字型（可換成你有安裝的其他中文字型名稱）
plt.rcParams['axes.unicode_minus'] = False      # 解決負號顯示錯誤問題

src = cv2.imread("snow1.jpg", cv2.IMREAD_GRAYSCALE)
# subplot()第一個2是代表垂直有2張圖, 第二個2是代表左右有2張圖，第三個參數是代表子圖編號
plt.subplot(221)                                # 建立子圖 1
plt.title("第一張")
plt.imshow(src, 'gray')                         # 灰階顯示第1張圖 
plt.subplot(222)                                # 建立子圖2
plt.title("第二張")
plt.hist(src.ravel(), 256)                      # 降維再繪製直方圖 
plt.subplot(223)                                # 建立子圖3
plt.title("第三張")
dst = cv2.equalizeHist(src)                     # 均衡化處理 
plt.imshow(dst, 'gray')                         # 顯示執行均衡化的結果影像
plt.subplot(224)                                # 建立子圖4
plt.title("第四張")
plt.hist(dst.ravel(), 256)                      # 降維再繪製直方圖
plt.tight_layout()                              # 自動調整排版
plt.show()

# %%
# 直方圖均衡化：
# 使用equalizeHist() 函式

import cv2
import matplotlib.pyplot as plt

# 設定全域字體為黑體，解決中文亂碼
plt.rcParams['font.sans-serif'] = ['SimHei']    # 指定字型（可換成你有安裝的其他中文字型名稱）
plt.rcParams['axes.unicode_minus'] = False      # 解決負號顯示錯誤問題

src = cv2.imread("springfield.jpg", cv2.IMREAD_GRAYSCALE)
# subplot()第一個2是代表垂直有2張圖, 第二個2是代表左右有2張圖，第三個參數是代表子圖編號
plt.subplot(221)                                # 建立子圖 1
plt.title("第一張")
plt.imshow(src, 'gray')                         # 灰階顯示第1張圖 
plt.subplot(222)                                # 建立子圖2
plt.title("第二張")
plt.hist(src.ravel(), 256)                      # 降維再繪製直方圖 
plt.subplot(223)                                # 建立子圖3
plt.title("第三張")
dst = cv2.equalizeHist(src)                     # 均衡化處理 
plt.imshow(dst, 'gray')                         # 顯示執行均衡化的結果影像
plt.subplot(224)                                # 建立子圖4
plt.title("第四張")
plt.hist(dst.ravel(), 256)                      # 降維再繪製直方圖
plt.tight_layout()                              # 自動調整排版
plt.show()

# %%
# 直方圖均衡化：除霧應用
import cv2
import matplotlib.pyplot as plt

# 設定全域字體為黑體，解決中文亂碼
plt.rcParams['font.sans-serif'] = ['SimHei']    # 指定字型（可換成你有安裝的其他中文字型名稱）
plt.rcParams['axes.unicode_minus'] = False      # 解決負號顯示錯誤問題

src = cv2.imread("highway1.png", cv2.IMREAD_GRAYSCALE)
# subplot()第一個2是代表垂直有2張圖, 第二個2是代表左右有2張圖，第三個參數是代表子圖編號
plt.subplot(221)                                # 建立子圖 1
plt.title("第一張")
plt.imshow(src, 'gray')                         # 灰階顯示第1張圖 
plt.subplot(222)                                # 建立子圖2
plt.title("第二張")
plt.hist(src.ravel(), 256)                      # 降維再繪製直方圖 
plt.subplot(223)                                # 建立子圖3
plt.title("第三張")
dst = cv2.equalizeHist(src)                     # 均衡化處理 
plt.imshow(dst, 'gray')                         # 顯示執行均衡化的結果影像
plt.subplot(224)                                # 建立子圖4
plt.title("第四張")
plt.hist(dst.ravel(), 256)                      # 降維再繪製直方圖
plt.tight_layout()                              # 自動調整排版
plt.show()

# %%
# 直方圖均衡化
# 應用於彩色影像

import cv2
import matplotlib.pyplot as plt

src = cv2.imread("springfield.jpg", cv2.IMREAD_COLOR)
cv2.imshow("Src", src)
plt.axis("off")
plt.imshow(cv2.cvtColor(src, cv2.COLOR_BGR2RGB))
plt.show()
(b, g, r) = cv2.split(src)              # 拆開彩色影像通道
blue = cv2.equalizeHist(b)              # 均衡化 B 通道
green = cv2.equalizeHist(g)             # 均衡化 G 通道
red = cv2.equalizeHist(r)               # 均衡化 R 通道
dst = cv2.merge((blue, green, red))     # 合併通道
cv2.imshow("Dst", dst)
plt.axis("off")
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 直方圖均衡化的缺點
import cv2
import matplotlib.pyplot as plt

# 設定全域字體為黑體，解決中文亂碼
plt.rcParams['font.sans-serif'] = ['SimHei']    # 指定字型（可換成你有安裝的其他中文字型名稱）
plt.rcParams['axes.unicode_minus'] = False      # 解決負號顯示錯誤問題

src = cv2.imread("office.jpg", cv2.IMREAD_GRAYSCALE)
cv2.imshow("Src", src)
plt.axis("off")
plt.title("原始影像")
plt.imshow(cv2.cvtColor(src, cv2.COLOR_BGR2RGB))
plt.show()
equ = cv2.equalizeHist(src) 
cv2.imshow("euualizeHist", equ)
plt.axis("off")
plt.title("均衡化後的缺點")
plt.imshow(cv2.cvtColor(equ, cv2.COLOR_BGR2RGB))
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 對比限制自適應直方圖均衡化
import cv2
import matplotlib.pyplot as plt

# 設定全域字體為黑體，解決中文亂碼
plt.rcParams['font.sans-serif'] = ['SimHei']    # 指定字型（可換成你有安裝的其他中文字型名稱）
plt.rcParams['axes.unicode_minus'] = False      # 解決負號顯示錯誤問題

src = cv2.imread("office.jpg", cv2.IMREAD_GRAYSCALE)
cv2.imshow("Src", src)
plt.axis("off")
plt.title("原始影像")
plt.imshow(cv2.cvtColor(src, cv2.COLOR_BGR2RGB))
plt.show()
# 建立一個CLAHE物件
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
# 把CLAHE物件應用在原始影像
dst = clahe.apply(src)
cv2.imshow("CLAHE", dst)
plt.axis("off")
plt.title("CLAHE後的影像")
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()
